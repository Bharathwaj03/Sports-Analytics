# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'C:\Users\Bharathwaj\Sports\IPL_ball_by_ball_updated.csv')

# %%
df
# Out:
#         match_id  season  start_date                             venue  \
# 0         335982    2008  2008-04-18             M Chinnaswamy Stadium
# 1         335982    2008  2008-04-18             M Chinnaswamy Stadium
# 2         335982    2008  2008-04-18             M Chinnaswamy Stadium
# 3         335982    2008  2008-04-18             M Chinnaswamy Stadium
# 4         335982    2008  2008-04-18             M Chinnaswamy Stadium
# ...          ...     ...         ...                               ...
# 225948   1312200    2022  2022-05-29  Narendra Modi Stadium, Ahmedabad
# 225949   1312200    2022  2022-05-29  Narendra Modi Stadium, Ahmedabad
# 225950   1312200    2022  2022-05-29  Narendra Modi Stadium, Ahmedabad
# 225951   1312200    2022  2022-05-29  Narendra Modi Stadium, Ahmedabad
# 225952   1312200    2022  2022-05-29  Narendra Modi Stadium, Ahmedabad
#
#         innings  ball           batting_team                 bowling_team  \
# 0             1   0.1  Kolkata Knight Riders  Royal Challengers Bangalore
# 1             1   0.2  Kolkata Knight Riders  Royal Challengers Bangalore
# 2             1   0.3  Kolkata Knight Riders  Royal Challengers Bangalore
# 3             1   0.4  Kolkata Knight Riders  Royal Challengers Bangalore
# 4             1   0.5  Kolkata Knight Riders  Royal Challengers Bangalore
# ...         ...   ...                    ...                          ...
# 225948        2  17.3         Gujarat Titans             Rajasthan Royals
# 225949        2  17.4         Gujarat Titans             Rajasthan Royals
# 225950        2  17.5         Gujarat Titans             Rajasthan Royals
# 225951        2  17.6         Gujarat Titans             Rajasthan Royals
# 225952        2  18.1         Gujarat Titans             Rajasthan Royals
#
#              striker   non_striker  ... extras  wides  noballs  byes  legbyes  \
# 0         SC Ganguly   BB McCullum  ...      1    NaN      NaN   NaN      1.0
# 1        BB McCullum    SC Ganguly  ...      0    NaN      NaN   NaN      NaN
# 2        BB McCullum    SC Ganguly  ...      1    1.0      NaN   NaN      NaN
# 3        BB McCullum    SC Ganguly  ...      0    NaN      NaN   NaN      NaN
# 4        BB McCullum    SC Ganguly  ...      0    NaN      NaN   NaN      NaN
# ...              ...           ...  ...    ...    ...      ...   ...      ...
# 225948     DA Miller  Shubman Gill  ...      0    NaN      NaN   NaN      NaN
# 225949  Shubman Gill     DA Miller  ...      0    NaN      NaN   NaN      NaN
# 225950  Shubman Gill     DA Miller  ...      0    NaN      NaN   NaN      NaN
# 225951     DA Miller  Shubman Gill  ...      0    NaN      NaN   NaN      NaN
# 225952  Shubman Gill     DA Miller  ...      0    NaN      NaN   NaN      NaN
#
#         penalty  wicket_type  player_dismissed other_wicket_type  \
# 0           NaN          NaN               NaN               NaN
# 1           NaN          NaN               NaN               NaN
# 2           NaN          NaN               NaN               NaN
# 3           NaN          NaN               NaN               NaN
# 4           NaN          NaN               NaN               NaN
# ...         ...          ...               ...               ...
# 225948      NaN          NaN               NaN               NaN
# 225949      NaN          NaN               NaN               NaN
# 225950      NaN          NaN               NaN               NaN
# 225951      NaN          NaN               NaN               NaN
# 225952      NaN          NaN               NaN               NaN
#
#        other_player_dismissed
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ...                       ...
# 225948                    NaN
# 225949                    NaN
# 225950                    NaN
# 225951                    NaN
# 225952                    NaN
#
# [225953 rows x 22 columns]

# %%
df_filter1 = df[(df['striker'] == "AB de Villiers")]

# %%
#df_mali.info()

# %%
kohli = kohli.query('wicket_type != "run out"')

# %%
batsman_stats = kohli.groupby('bowler').agg({
    'ball': 'count',               # Total number of balls faced
    'runs_off_bat': 'sum',         # Total number of runs scored
    'player_dismissed': 'count'    # Number of times dismissed
}).reset_index()

# Renaming columns for clarity
batsman_stats.columns = ['bowler', 'balls_faced', 'runs_scored', 'times_dismissed']

# %%
batsman_stats['strike_rate'] = (batsman_stats['runs_scored'] / batsman_stats['balls_faced']) * 100

# %%
batsman_stats.to_csv('abd_b2b.csv' , sep=',', index = True, encoding='utf-8')

# %%
# Define the Pandas UDF
def get_player_stats(df, batsman, bowler):
    filtered_df = df[(df['striker'] == batsman) & (df['bowler'] == bowler)]
    runs_scored = filtered_df['runs_off_bat'].sum()
    balls_bowled = filtered_df.shape[0]
    wickets_taken = filtered_df.loc[df['wicket_type'].notnull(), 'wicket_type'].count()
    strike_rate = (runs_scored / balls_bowled) * 100
    dot_balls =  filtered_df.loc[(df['runs_off_bat'] == 0), 'runs_off_bat'].count()
    fours = filtered_df.loc[(df['runs_off_bat'] == 4), 'runs_off_bat'].count()
    sixes = filtered_df.loc[(df['runs_off_bat'] == 6), 'runs_off_bat'].count()
    average = (runs_scored/wickets_taken)
    dot_percentage = (dot_balls/balls_bowled) * 100
    boundary_percentage = ((fours + sixes)/balls_bowled) * 100
    
    stats = {
        "runs": runs_scored,
        "balls": balls_bowled,
        "wickets": wickets_taken,
        "dots": dot_balls,
        "strike_rate": strike_rate,
        "4s": fours,
        "6s": sixes,
        "avg": average,
        "dot%": dot_percentage,
        "boundary%": boundary_percentage}
    return stats

# %%
# Call the UDF with desired parameters
batsman_name = "MS Dhoni"
bowler_name = "SL Malinga"
stats = get_player_stats(df, batsman_name, bowler_name)

# Display the results
stats
# Out:
# {'runs': 89,
#  'balls': 64,
#  'wickets': 2,
#  'dots': 21,
#  'strike_rate': 139.0625,
#  '4s': 5,
#  '6s': 5,
#  'dot%': 32.8125,
#  'boundary%': 15.625}

# %%
# Call the UDF with desired parameters
batsman_name = "V Kohli"
bowler_name = "SL Malinga"
stats = get_player_stats(df, batsman_name, bowler_name)
# Display the results
stats
# Out:
# C:\Users\BHARAT~1\AppData\Local\Temp/ipykernel_6900/1722422345.py:11: RuntimeWarning: divide by zero encountered in longlong_scalars
#   average = (runs_scored/wickets_taken)
# {'runs': 34,
#  'balls': 38,
#  'wickets': 0,
#  'dots': 15,
#  'strike_rate': 89.47368421052632,
#  '4s': 3,
#  '6s': 0,
#  'avg': inf,
#  'dot%': 39.473684210526315,
#  'boundary%': 7.894736842105263}

# %%
# Call the UDF with desired parameters
batsman_name = "AB de Villiers"
bowler_name = "SL Malinga"
stats = get_player_stats(df, batsman_name, bowler_name)
# Display the results
stats
# Out:
# {'runs': 124,
#  'balls': 64,
#  'wickets': 1,
#  'dots': 18,
#  'strike_rate': 193.75,
#  '4s': 10,
#  '6s': 8,
#  'avg': 124.0,
#  'dot%': 28.125,
#  'boundary%': 28.125}

# %%
# Call the UDF with desired parameters
batsman_name = "AB de Villiers"
bowler_name = "SL Malinga"
stats = get_player_stats(df, batsman_name, bowler_name)
# Display the results
stats
# Out:
# {'runs': 124,
#  'balls': 64,
#  'wickets': 1,
#  'dots': 18,
#  'strike_rate': 193.75,
#  '4s': 10,
#  '6s': 8,
#  'avg': 124.0,
#  'dot%': 28.125,
#  'boundary%': 28.125}
